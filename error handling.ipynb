# %%
#two type of error 
compilation time  -- syntax (
execution time----- exception ( ram mei run)
syntax error - something in program is not written according to program grammer

# %%
print"hello"
# Out:
#   Cell In[1], line 1
#     print"hello"
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
#syntax error
print"hello"
# Out:
#   Cell In[2], line 2
#     print"hello"
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
prnt("hello"):
def fn :

# %%
#other example of syntax error
# missing colon(if,function) or bracket
#misspelling a keyword
#incorect indentation
# empty if,else,loop,function

# %%
a=5
if a==3:
    print(a)
# Out:
#   Cell In[2], line 3
#     print(a)
#     ^
# IndentationError: expected an indented block after 'if' statement on line 2

# %%
#index error
l=[1,2,3]
l[4]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 3
#       1 #index error
#       2 l=[1,2,3]
# ----> 3 l[4]
#
# IndexError: list index out of range

# %%
# modulenotfounterror
import mathi
mathi.floor(1.6)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 2
#       1 # modulenotfounterror
# ----> 2 import mathi
#       3 mathi.floor(1.6)
#
# ModuleNotFoundError: No module named 'mathi'

# %%
#key error (in dict when key is not found)
d={'name':'renu'}
d['age']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[5], line 3
#       1 #key error (in dict when key is not found)
#       2 d={'name':'renu'}
# ----> 3 d['age']
#
# KeyError: 'age'

# %%
#value error
#is thrown when a function argument is of an inappropriate type
int('a')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 3
#       1 #value error
#       2 #is thrown when a function argument is of an inappropriate type
# ----> 3 int('a')
#
# ValueError: invalid literal for int() with base 10: 'a'

# %%
#type error is thrown when an operation and function is applied to an object of 
#inappropriate type
1+'a'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 3
#       1 #type error is thrown when an operation and function is applied to an object of
#       2 #inappropriate type
# ----> 3 1+'a'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
#attribute error
l=[1,2,3]
l.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 2
#       1 l=[1,2,3]
# ----> 2 l.upper()
#
# AttributeError: 'list' object has no attribute 'upper'

# %%
# name error

print(a)  # a doen not exist
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 # name error
# ----> 3 print(a)
#
# NameError: name 'a' is not defined

# %%
# exception error
#memory overflow
#divided by 0--logical error
#database error  # database is not present

# %%
#why it is important to handle
user experiance
safty purpose code is visible to every one (website)
#how to handle exception
#try except block

# %%
try:
    x = int("abc")
except ValueError:
    print("Conversion failed!")
# Out:
# Conversion failed!

# %%
try: Code that might cause an error

except: Handles the error

else: Runs if no error occurs

finally: Runs always (cleanup code)

# %%
try:
    x = 10 / 2
except ZeroDivisionError:
    print("Cannot divide by zero!")
else:
    print("No error occurred.")
finally:
    print("This runs no matter what.")
# Out:
# No error occurred.
# This runs no matter what.

# %%
#Catching Multiple Errors
try:
    num = int(input("Enter number: "))
    result = 10 / num
except ValueError:
    print("You entered an invalid number.")
except ZeroDivisionError:
    print("Cannot divide by zero.")

# %%
Why raise exceptions?

Stop execution when invalid data occurs
Signal errors clearly for debugging or handling

# %%
age = -5
if age < 0:
    raise ValueError("Age cannot be negative")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 3
#       1 age = -5
#       2 if age < 0:
# ----> 3     raise ValueError("Age cannot be negative")
#
# ValueError: Age cannot be negative

# %%
try:
    with open("data.txt", "r") as f:
        content = f.read()
        print(content)

except FileNotFoundError:
    print("File not found, please check the name!")
